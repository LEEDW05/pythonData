# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #서울특별시 유기동물 현황 확인하기

# %% [markdown]
# ##1.공공데이터 수집하기
# * data.seoul.go.kr 접속
# * "서울시 유기동물보호현황 통계" 검색
# * excel(셀병합 해제), csv, txt 각각 다운로드하여 저장
# * colab 왼쪽에 파일을 클릭하여 생성한 폴더에 모두 업로드

# %% [markdown]
# ##2.데이터 읽어오기

# %% [markdown]
# ###(1) 정형 데이터를 관리하기 위한 라이브러리 선언하기

# %%
# pandas 라이브러리 선언

import pandas as pd

# %% [markdown]
# ###(2) excel 화일(유기동물보호현황.xlsx) 읽고 데이터 확인하기

# %%
# 변수명 = pd.read_excel('파일경로명', 속성들)

exceldata = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/유기동물보호+현황_20250117094909.xlsx')
exceldata
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     자치구별(1)  자치구별(2)  2023 2023.1  2023.2 2023.3 2023.4 2023.5 2023.6  2023.7  \
# 0   자치구별(1)  자치구별(2)    합계     합계      합계     합계     합계     합계     합계      합계
# 1   자치구별(1)  자치구별(2)    소계      개       개      개      개      개    고양이     고양이
# 2   자치구별(1)  자치구별(2)    소계     소계  인도(주인)   입양분양  폐사안락사   계류기증     소계  인도(주인)
# 3        합계       소계  5176   2428    1134    702    565     27   2307      84
# 4        합계      종로구   161     67      29      9     29      -     86       2
# 5        합계       중구   100     33      21      7      5      -     51       1
# 6        합계      용산구   237    116      81     32      3      -    109      21
# 7        합계      성동구   175     53      22     23      8      -    107       -
# ...

# %% [markdown]
# ###(3)텍스트 화일(유기동물보호현황.txt) 읽고 데이터 확인하기

# %%
# 변수명 = pd.read_csv(‘파일경로명', 속성들)

txtdata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/유기동물보호+현황_20250117094906.txt')
txtdata
# Out:
#    자치구별(1)\t자치구별(2)\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023\t2023
# 0   자치구별(1)\t자치구별(2)\t합계\t합계\t합계\t합계\t합계\t합계\t합계\t...
# 1   자치구별(1)\t자치구별(2)\t소계\t개\t개\t개\t개\t개\t고양이\t고양이\...
# 2   자치구별(1)\t자치구별(2)\t소계\t소계\t인도(주인)\t입양분양\t폐사안락사\...
# 3   합계\t소계\t5176\t2428\t1134\t702\t565\t27\t2307\t...
# 4   합계\t종로구\t161\t67\t29\t9\t29\t-\t86\t2\t13\t69\...
# 5   합계\t중구\t100\t33\t21\t7\t5\t-\t51\t1\t14\t35\t1...
# 6   합계\t용산구\t237\t116\t81\t32\t3\t-\t109\t21\t24\t...
# 7   합계\t성동구\t175\t53\t22\t23\t8\t-\t107\t-\t49\t58...
# 8   합계\t광진구\t177\t79\t34\t33\t12\t-\t84\t2\t25\t57...
# 9   합계\t동대문구\t217\t76\t30\t31\t13\t2\t120\t11\t51\...
# 10  합계\t중랑구\t222\t104\t47\t42\t12\t3\t105\t-\t22\t...
# 11  합계\t성북구\t193\t88\t49\t17\t21\t1\t84\t2\t13\t69...
# 12  합계\t강북구\t238\t140\t56\t36\t48\t-\t81\t2\t26\t5...
# 13  합계\t도봉구\t186\t117\t56\t39\t21\t1\t61\t-\t15\t4...
# 14  합계\t노원구\t188\t129\t49\t31\t48\t1\t53\t2\t9\t42...
# ...

# %% [markdown]
# ###(4) tab으로 구분된 텍스트 화일(유기동물보호현황.txt) 읽어오기

# %%
# 변수명 = pd.read_csv(파일경로명, 속성들)
# 속성 : delimiter='구분기호', 생략시 ","로 인식, \t: tab을 열 구분 문자로 인식
txtdata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/유기동물보호+현황_20250117094906.txt',delimiter='\t')
txtdata
# Out:
#     자치구별(1)  자치구별(2)  2023 2023.1  2023.2 2023.3 2023.4 2023.5 2023.6  2023.7  \
# 0   자치구별(1)  자치구별(2)    합계     합계      합계     합계     합계     합계     합계      합계
# 1   자치구별(1)  자치구별(2)    소계      개       개      개      개      개    고양이     고양이
# 2   자치구별(1)  자치구별(2)    소계     소계  인도(주인)   입양분양  폐사안락사   계류기증     소계  인도(주인)
# 3        합계       소계  5176   2428    1134    702    565     27   2307      84
# 4        합계      종로구   161     67      29      9     29      -     86       2
# 5        합계       중구   100     33      21      7      5      -     51       1
# 6        합계      용산구   237    116      81     32      3      -    109      21
# 7        합계      성동구   175     53      22     23      8      -    107       -
# 8        합계      광진구   177     79      34     33     12      -     84       2
# 9        합계     동대문구   217     76      30     31     13      2    120      11
# 10       합계      중랑구   222    104      47     42     12      3    105       -
# ...

# %% [markdown]
# ### (5) csv 화일(유기동물보호현황.csv) 읽어오기

# %%
# 변수명 = pd.read_csv('파일경로명', 속성들)

csvdata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/유기동물보호+현황_20250117094901.csv', header=3)
csvdata
# Out:
#    자치구별(1) 자치구별(2)    소계  소계.1  인도(주인)  입양분양  폐사안락사 계류기증  소계.2 인도(주인).1  \
# 0       합계      소계  5176  2428    1134   702    565   27  2307       84
# 1       합계     종로구   161    67      29     9     29    -    86        2
# 2       합계      중구   100    33      21     7      5    -    51        1
# 3       합계     용산구   237   116      81    32      3    -   109       21
# 4       합계     성동구   175    53      22    23      8    -   107        -
# 5       합계     광진구   177    79      34    33     12    -    84        2
# 6       합계    동대문구   217    76      30    31     13    2   120       11
# 7       합계     중랑구   222   104      47    42     12    3   105        -
# 8       합계     성북구   193    88      49    17     21    1    84        2
# 9       합계     강북구   238   140      56    36     48    -    81        2
# 10      합계     도봉구   186   117      56    39     21    1    61        -
# 11      합계     노원구   188   129      49    31     48    1    53        2
# ...

# %% [markdown]
# (5)-1. encoding = '인코딩방식'
#   - 한글이 깨져서 보일 경우 인코딩 방식 설정
#   - UTF-8 : 가변길이 문자 인코딩 방식,조합형 방식
#   - EUC-KR : 한글을 2Byte로 변환, 완성형 문자 인코딩 방식
#   - cp949 : EUC-KR 확장버전, MS office에서 저장한 파일 형식

# %%
# 변수명 = pd.read_csv(파일경로명, 속성들)

# %% [markdown]
# (5)-2. 데이터 정보 확인하기
# 데이터타입, 각 행열의 개수, 누락데이터 수등 확인한 후 다음 물음에 답하세요.
#
#
#
# - 행과 열은 어떻게 구성되어 있는가?
# - 열의 이름들은 무엇인가?
# - 범주형 데이터와 수치형 데이터는 무엇인가?

# %%
# 변수명.info()

csvdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   자치구별(1)   26 non-null     object
#  1   자치구별(2)   26 non-null     object
#  2   소계        26 non-null     int64
#  3   소계.1      26 non-null     int64
#  4   인도(주인)    26 non-null     int64
#  5   입양분양      26 non-null     int64
#  6   폐사안락사     26 non-null     int64
#  7   계류기증      26 non-null     object
#  8   소계.2      26 non-null     int64
#  9   인도(주인).1  26 non-null     object
#  10  입양분양.1    26 non-null     int64
#  11  폐사안락사.1   26 non-null     int64
#  12  계류기증.1    26 non-null     object
#  13  소계.3      26 non-null     int64
#  14  인도(주인).2  26 non-null     object
#  15  입양분양.2    26 non-null     int64
#  16  폐사안락사.2   26 non-null     int64
#  17  계류기증.2    26 non-null     object
# dtypes: int64(11), object(7)
# memory usage: 3.8+ KB

# %% [markdown]
# ###(6) csv 화일(유기동물보호현황.csv)에서 특정 행을 header로 설정하여 읽어오기
# - 2번째 행을 열이름으로 설정하기
# - 읽어온 데이터를 csvData 변수에 저장하기
# - 상위 5개의 데이터 확인하기

# %%
# 변수명 = pd.read_csv(파일경로명, header=[], encoding='코딩방식')
# header=[행번호] : 위에서 몇 째줄 부터 읽어올지 지정(줄 수는 0부터 시작)
# header=[2] : 2번째 행을 열이름으로 설정

# %% [markdown]
# (6)-1. 데이터의 정보 확인하기
# - 행과 열은 어떻게 구성되어 있는가?
# - 열의 이름들은 무엇인가?
# - 범주형 데이터와 수치형 데이터는 무엇인가?

# %% [markdown]
# ###(7) csv 화일(유기동물보호현황.csv)에서 2개의 행을 header로 읽어오기
# - 1번째와 2번째 행을 열이름으로 설정, header=[1, 2]
# - 읽어온 데이터를 data 변수에 저장
# - 상위 5개의 데이터 확인하기

# %%
csvdata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/유기동물보호+현황_20250117094901.csv', header=3)
csvdata.head(5)
csvdata.tail(2)
# Out:
#    자치구별(1) 자치구별(2)   소계  소계.1  인도(주인)  입양분양  폐사안락사 계류기증  소계.2 인도(주인).1  \
# 24      합계     송파구  249    73      35    25     13    -   122        3
# 25      합계     강동구  270   136      71    50     10    5   122        2
#
#     입양분양.1  폐사안락사.1 계류기증.1  소계.3 인도(주인).2  입양분양.2  폐사안락사.2 계류기증.2
# 24      32       87      -    54        1      26       27      -
# 25      59       60      1    12        -       4        8      -

# %% [markdown]
# (7)-1. 데이터의 정보 확인하기
# - 행과 열은 어떻게 구성되어 있는가?
# - 열의 이름들은 무엇인가?
# - 범주형 데이터와 수치형 데이터는 무엇인가?

# %% [markdown]
# ###(8) csv 화일(유기동물보호현황.csv) 읽어오기
# - 1번째와 2번째 행을 열이름으로 설정
# - 숫자에 ','가 있는 데이터의 ','는 모두 제거
# - 상위 5개의 데이터 확인하기

# %%
# 변수명 = pd.read_csv(파일경로명, 속성들)
#thousands=',' : ','가 포함된 문자열 데이터에서 ','를 삭제하고 숫자형 데이터를 변경

# %% [markdown]
# (8)-1. 데이터의 정보 확인하기
# - 행과 열은 어떻게 구성되어 있는가?
# - 열의 이름들은 무엇인가?
# - 범주형 데이터와 수치형 데이터는 무엇인가?
